# %%
# !gdown 12cgRU3lOjPOIVt-iKPDZhhqaJBCN2EBH
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=12cgRU3lOjPOIVt-iKPDZhhqaJBCN2EBH
# To: /content/HousePricePrediction.xlsx
# 100% 219k/219k [00:00<00:00, 96.1MB/s]

# %%
# Importing the libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_excel('HousePricePrediction.xlsx')
# Printing first 5 records of the dataset
df.head()
# Out:
#    Id  MSSubClass MSZoning  LotArea LotConfig BldgType  OverallCond  \
# 0   0          60       RL     8450    Inside     1Fam            5
# 1   1          20       RL     9600       FR2     1Fam            8
# 2   2          60       RL    11250    Inside     1Fam            5
# 3   3          70       RL     9550    Corner     1Fam            5
# 4   4          60       RL    14260       FR2     1Fam            5
#
#    YearBuilt  YearRemodAdd Exterior1st  BsmtFinSF2  TotalBsmtSF  SalePrice
# 0       2003          2003     VinylSd         0.0        856.0   208500.0
# 1       1976          1976     MetalSd         0.0       1262.0   181500.0
# 2       2001          2002     VinylSd         0.0        920.0   223500.0
# 3       1915          1970     Wd Sdng         0.0        756.0   140000.0
# 4       2000          2000     VinylSd         0.0       1145.0   250000.0

# %%
df.shape  #checking the dimension
# Out:
# (2919, 13)

# %% [markdown]
# **Data PreProcessing**

# %% [markdown]
# Now, we categorize the features depending on their datatype (int, float, object) and then calculate their total number.

# %%
obj = (df.dtypes == 'object')
object_cols = list(obj[obj].index)
print("Categorical variables:",len(object_cols))

int_ = (df.dtypes == 'int')
num_cols = list(int_[int_].index)
print("Integer variables:",len(num_cols))

fl = (df.dtypes == 'float')
fl_cols = list(fl[fl].index)
print("Float variables:",len(fl_cols))
# Out:
# Categorical variables: 4
# Integer variables: 6
# Float variables: 3

# %% [markdown]
# **Exploratory Data Analysis**
#
# EDA refers to the deep analysis of data so as to discover different patterns and spot anomalies. Before making inferences from data it is essential to examine all the variables.

# %%
# Select only numerical features for correlation analysis
numerical_df = df.select_dtypes(include=['number'])

# Calculate the correlation matrix
corr = numerical_df.corr(method='spearman')

# Plot the correlation matrix with a gradient color map
corr.style.background_gradient(cmap='coolwarm')
# Out:
# <style type="text/css">
# #T_4594f_row0_col0, #T_4594f_row1_col1, #T_4594f_row2_col2, #T_4594f_row3_col3, #T_4594f_row4_col4, #T_4594f_row5_col5, #T_4594f_row6_col6, #T_4594f_row7_col7, #T_4594f_row8_col8 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_4594f_row0_col1 {
#   background-color: #8caffe;
#   color: #000000;
# }
# #T_4594f_row0_col2, #T_4594f_row6_col4 {
#   background-color: #85a8fc;
#   color: #f1f1f1;
# }
# #T_4594f_row0_col3 {
#   background-color: #9ebeff;
#   color: #000000;
# }
# #T_4594f_row0_col4, #T_4594f_row6_col2 {
#   background-color: #9abbff;
#   color: #000000;
# }
# #T_4594f_row0_col5 {
#   background-color: #4e68d8;
#   color: #f1f1f1;
# }
# #T_4594f_row0_col6 {
#   background-color: #5d7ce6;
#   color: #f1f1f1;
# }
# #T_4594f_row0_col7 {
#   background-color: #80a3fa;
#   color: #f1f1f1;
# }
# #T_4594f_row0_col8 {
#   background-color: #5977e3;
#   color: #f1f1f1;
# }
# #T_4594f_row1_col0 {
#   background-color: #4a63d3;
#   color: #f1f1f1;
# }
# #T_4594f_row1_col2, #T_4594f_row1_col7, #T_4594f_row2_col1, #T_4594f_row3_col4, #T_4594f_row3_col8, #T_4594f_row4_col3, #T_4594f_row5_col0, #T_4594f_row5_col6, #T_4594f_row6_col5 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# #T_4594f_row1_col3, #T_4594f_row5_col1 {
#   background-color: #8db0fe;
#   color: #000000;
# }
# #T_4594f_row1_col4, #T_4594f_row5_col2 {
#   background-color: #a5c3fe;
#   color: #000000;
# }
# #T_4594f_row1_col5, #T_4594f_row1_col8 {
#   background-color: #5f7fe8;
#   color: #f1f1f1;
# }
# #T_4594f_row1_col6, #T_4594f_row4_col6 {
#   background-color: #3f53c6;
#   color: #f1f1f1;
# }
# #T_4594f_row2_col0, #T_4594f_row8_col0 {
#   background-color: #4257c9;
#   color: #f1f1f1;
# }
# #T_4594f_row2_col3 {
#   background-color: #89acfd;
#   color: #000000;
# }
# #T_4594f_row2_col4, #T_4594f_row7_col5 {
#   background-color: #bbd1f8;
#   color: #000000;
# }
# #T_4594f_row2_col5 {
#   background-color: #7a9df8;
#   color: #f1f1f1;
# }
# #T_4594f_row2_col6 {
#   background-color: #6c8ff1;
#   color: #f1f1f1;
# }
# #T_4594f_row2_col7 {
#   background-color: #dedcdb;
#   color: #000000;
# }
# #T_4594f_row2_col8 {
#   background-color: #e1dad6;
#   color: #000000;
# }
# #T_4594f_row3_col0 {
#   background-color: #485fd1;
#   color: #f1f1f1;
# }
# #T_4594f_row3_col1 {
#   background-color: #779af7;
#   color: #f1f1f1;
# }
# #T_4594f_row3_col2 {
#   background-color: #7396f5;
#   color: #f1f1f1;
# }
# #T_4594f_row3_col5 {
#   background-color: #455cce;
#   color: #f1f1f1;
# }
# #T_4594f_row3_col6 {
#   background-color: #799cf8;
#   color: #f1f1f1;
# }
# #T_4594f_row3_col7 {
#   background-color: #4c66d6;
#   color: #f1f1f1;
# }
# #T_4594f_row4_col0 {
#   background-color: #4358cb;
#   color: #f1f1f1;
# }
# #T_4594f_row4_col1 {
#   background-color: #92b4fe;
#   color: #000000;
# }
# #T_4594f_row4_col2 {
#   background-color: #aac7fd;
#   color: #000000;
# }
# #T_4594f_row4_col5 {
#   background-color: #f59d7e;
#   color: #000000;
# }
# #T_4594f_row4_col7 {
#   background-color: #edd1c2;
#   color: #000000;
# }
# #T_4594f_row4_col8, #T_4594f_row8_col7 {
#   background-color: #f7af91;
#   color: #000000;
# }
# #T_4594f_row5_col3, #T_4594f_row8_col1 {
#   background-color: #8badfd;
#   color: #000000;
# }
# #T_4594f_row5_col4 {
#   background-color: #ee8669;
#   color: #f1f1f1;
# }
# #T_4594f_row5_col7 {
#   background-color: #d5dbe5;
#   color: #000000;
# }
# #T_4594f_row5_col8 {
#   background-color: #f4c6af;
#   color: #000000;
# }
# #T_4594f_row6_col0 {
#   background-color: #4961d2;
#   color: #f1f1f1;
# }
# #T_4594f_row6_col1 {
#   background-color: #6f92f3;
#   color: #f1f1f1;
# }
# #T_4594f_row6_col3 {
#   background-color: #b5cdfa;
#   color: #000000;
# }
# #T_4594f_row6_col7 {
#   background-color: #97b8ff;
#   color: #000000;
# }
# #T_4594f_row6_col8 {
#   background-color: #536edd;
#   color: #f1f1f1;
# }
# #T_4594f_row7_col0 {
#   background-color: #4055c8;
#   color: #f1f1f1;
# }
# #T_4594f_row7_col1 {
#   background-color: #3d50c3;
#   color: #f1f1f1;
# }
# #T_4594f_row7_col2 {
#   background-color: #dfdbd9;
#   color: #000000;
# }
# #T_4594f_row7_col3 {
#   background-color: #6687ed;
#   color: #f1f1f1;
# }
# #T_4594f_row7_col4 {
#   background-color: #f2c9b4;
#   color: #000000;
# }
# #T_4594f_row7_col6 {
#   background-color: #6e90f2;
#   color: #f1f1f1;
# }
# #T_4594f_row7_col8 {
#   background-color: #f6bea4;
#   color: #000000;
# }
# #T_4594f_row8_col2 {
#   background-color: #f0cdbb;
#   color: #000000;
# }
# #T_4594f_row8_col3 {
#   background-color: #7da0f9;
#   color: #f1f1f1;
# }
# #T_4594f_row8_col4 {
#   background-color: #f39778;
#   color: #000000;
# }
# #T_4594f_row8_col5 {
#   background-color: #f3c7b1;
#   color: #000000;
# }
# #T_4594f_row8_col6 {
#   background-color: #4f69d9;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_4594f" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_4594f_level0_col0" class="col_heading level0 col0" >Id</th>
#       <th id="T_4594f_level0_col1" class="col_heading level0 col1" >MSSubClass</th>
#       <th id="T_4594f_level0_col2" class="col_heading level0 col2" >LotArea</th>
#       <th id="T_4594f_level0_col3" class="col_heading level0 col3" >OverallCond</th>
#       <th id="T_4594f_level0_col4" class="col_heading level0 col4" >YearBuilt</th>
#       <th id="T_4594f_level0_col5" class="col_heading level0 col5" >YearRemodAdd</th>
#       <th id="T_4594f_level0_col6" class="col_heading level0 col6" >BsmtFinSF2</th>
#       <th id="T_4594f_level0_col7" class="col_heading level0 col7" >TotalBsmtSF</th>
#       <th id="T_4594f_level0_col8" class="col_heading level0 col8" >SalePrice</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_4594f_level0_row0" class="row_heading level0 row0" >Id</th>
#       <td id="T_4594f_row0_col0" class="data row0 col0" >1.000000</td>
#       <td id="T_4594f_row0_col1" class="data row0 col1" >0.010335</td>
#       <td id="T_4594f_row0_col2" class="data row0 col2" >-0.015878</td>
#       <td id="T_4594f_row0_col3" class="data row0 col3" >0.002473</td>
#       <td id="T_4594f_row0_col4" class="data row0 col4" >-0.015458</td>
#       <td id="T_4594f_row0_col5" class="data row0 col5" >-0.044102</td>
#       <td id="T_4594f_row0_col6" class="data row0 col6" >0.006067</td>
#       <td id="T_4594f_row0_col7" class="data row0 col7" >-0.023581</td>
#       <td id="T_4594f_row0_col8" class="data row0 col8" >-0.018546</td>
#     </tr>
#     <tr>
#       <th id="T_4594f_level0_row1" class="row_heading level0 row1" >MSSubClass</th>
#       <td id="T_4594f_row1_col0" class="data row1 col0" >0.010335</td>
#       <td id="T_4594f_row1_col1" class="data row1 col1" >1.000000</td>
#       <td id="T_4594f_row1_col2" class="data row1 col2" >-0.314604</td>
#       <td id="T_4594f_row1_col3" class="data row1 col3" >-0.063699</td>
#       <td id="T_4594f_row1_col4" class="data row1 col4" >0.033315</td>
#       <td id="T_4594f_row1_col5" class="data row1 col5" >0.016209</td>
#       <td id="T_4594f_row1_col6" class="data row1 col6" >-0.097622</td>
#       <td id="T_4594f_row1_col7" class="data row1 col7" >-0.303210</td>
#       <td id="T_4594f_row1_col8" class="data row1 col8" >0.007192</td>
#     </tr>
#     <tr>
#       <th id="T_4594f_level0_row2" class="row_heading level0 row2" >LotArea</th>
#       <td id="T_4594f_row2_col0" class="data row2 col0" >-0.015878</td>
#       <td id="T_4594f_row2_col1" class="data row2 col1" >-0.314604</td>
#       <td id="T_4594f_row2_col2" class="data row2 col2" >1.000000</td>
#       <td id="T_4594f_row2_col3" class="data row2 col3" >-0.081013</td>
#       <td id="T_4594f_row2_col4" class="data row2 col4" >0.123510</td>
#       <td id="T_4594f_row2_col5" class="data row2 col5" >0.102956</td>
#       <td id="T_4594f_row2_col6" class="data row2 col6" >0.060635</td>
#       <td id="T_4594f_row2_col7" class="data row2 col7" >0.354959</td>
#       <td id="T_4594f_row2_col8" class="data row2 col8" >0.456461</td>
#     </tr>
#     <tr>
#       <th id="T_4594f_level0_row3" class="row_heading level0 row3" >OverallCond</th>
#       <td id="T_4594f_row3_col0" class="data row3 col0" >0.002473</td>
#       <td id="T_4594f_row3_col1" class="data row3 col1" >-0.063699</td>
#       <td id="T_4594f_row3_col2" class="data row3 col2" >-0.081013</td>
#       <td id="T_4594f_row3_col3" class="data row3 col3" >1.000000</td>
#       <td id="T_4594f_row3_col4" class="data row3 col4" >-0.421910</td>
#       <td id="T_4594f_row3_col5" class

# %% [markdown]
# To analyze the different categorical features, we can draw a barplot.

# %%
#Analyzing categorical variables

unique_values = []
for col in object_cols:
  unique_values.append(df[col].unique().size)
plt.figure(figsize=(10,6))
plt.title('No. Unique values of Categorical Features')
plt.xticks(rotation=90)
sns.barplot(x=object_cols,y=unique_values)
# Out:
# <Axes: title={'center': 'No. Unique values of Categorical Features'}>

# %% [markdown]
# The plot shows that Exterior1st has around 16 unique categories and other features have around  6 unique categories. To findout the actual count of each category we can plot the bargraph of each four features separately.

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Assuming df is your DataFrame and object_cols is defined
plt.figure(figsize=(18, 36))
plt.title('Categorical Features: Distribution')
plt.xticks(rotation=90)

# Define your y-axis labels for each categorical feature
y_labels = ['MSZoning', 'LotConfig', 'BldgType', 'Exterior1st']

index = 1
for col in object_cols:
    y = df[col].value_counts()
    plt.subplot(11, 4, index)
    plt.xticks(rotation=90)
    sns.barplot(x=list(y.index), y=y)

    # Set the y-axis label based on the current index
    if index <= len(y_labels):
        plt.ylabel(y_labels[index - 1])  # Adjust for 0-based indexing

    index += 1
# Adjust spacing between subplots
plt.subplots_adjust(hspace=0.5, wspace=0.3)
# Out:
# <ipython-input-52-2201045250cd>:15: MatplotlibDeprecationWarning: Auto-removal of overlapping axes is deprecated since 3.6 and will be removed two minor releases later; explicitly call ax.remove() as needed.
#   plt.subplot(11, 4, index)

# %% [markdown]
# **Data Cleaning**
#
# Data Cleaning is the way to improvise the data or remove incorrect, corrupted or irrelevant data.
#
# As in our dataset, there are some columns that are not important and irrelevant for the model training. So, we can drop that column before training. There are 2 approaches to dealing with empty/null values
#
# We can easily delete the column/row (if the feature or record is not much important).
# Filling the empty slots with mean/mode/0/NA/etc. (depending on the dataset requirement).
# As Id Column will not be participating in any prediction. So we can Drop it.

# %%
#As Id Column will not be participating in any prediction. So we can Drop it.
df.drop(['Id'],
             axis=1,
             inplace=True)

# %%
#counting the total nulls in every column
null_counts = df.isnull().sum()
print(null_counts)
# Out:
# MSSubClass         0
# MSZoning           4
# LotArea            0
# LotConfig          0
# BldgType           0
# OverallCond        0
# YearBuilt          0
# YearRemodAdd       0
# Exterior1st        1
# BsmtFinSF2         1
# TotalBsmtSF        1
# SalePrice       1459
# dtype: int64

# %% [markdown]
# Replacing SalePrice empty values with their mean values to make the data distribution symmetric.

# %%
df['SalePrice'] = df['SalePrice'].fillna(
  df['SalePrice'].mean())

# %% [markdown]
# Drop records with null values (as the empty records are very less).

# %%
new_df = df.dropna()

# %% [markdown]
# Checking features which have null values in the new dataframe (if there are still any).

# %%
new_df.isnull().sum()
# Out:
# MSSubClass      0
# MSZoning        0
# LotArea         0
# LotConfig       0
# BldgType        0
# OverallCond     0
# YearBuilt       0
# YearRemodAdd    0
# Exterior1st     0
# BsmtFinSF2      0
# TotalBsmtSF     0
# SalePrice       0
# dtype: int64

# %%
object_cols = new_df.select_dtypes(include='object').columns
print("Categorical variables:")
print(list(object_cols))
print("No. of categorical features:", len(object_cols))
# Out:
# Categorical variables:
# ['MSZoning', 'LotConfig', 'BldgType', 'Exterior1st']
# No. of categorical features: 4

# %%
# creating dummy variables for categorical variables

df_final = pd.get_dummies(new_df, columns=object_cols, drop_first=False)
df_final.head()
# Out:
#    MSSubClass  LotArea  OverallCond  YearBuilt  YearRemodAdd  BsmtFinSF2  \
# 0          60     8450            5       2003          2003         0.0
# 1          20     9600            8       1976          1976         0.0
# 2          60    11250            5       2001          2002         0.0
# 3          70     9550            5       1915          1970         0.0
# 4          60    14260            5       2000          2000         0.0
#
#    TotalBsmtSF  SalePrice  MSZoning_C (all)  MSZoning_FV  ...  \
# 0        856.0   208500.0             False        False  ...
# 1       1262.0   181500.0             False        False  ...
# 2        920.0   223500.0             False        False  ...
# 3        756.0   140000.0             False        False  ...
# 4       1145.0   250000.0             False        False  ...
#
#    Exterior1st_CemntBd  Exterior1st_HdBoard  Exterior1st_ImStucc  \
# 0                False                False                False
# 1                False                False                False
# 2                False                False                False
# 3                False                False                False
# 4                False                False                False
#
#    Exterior1st_MetalSd  Exterior1st_Plywood  Exterior1st_Stone  \
# 0                False                False              False
# 1                 True                False              False
# 2                False                False              False
# 3                False                False              False
# 4                False                False              False
#
#    Exterior1st_Stucco  Exterior1st_VinylSd  Exterior1st_Wd Sdng  \
# 0               False                 True                False
# 1               False                False                False
# 2               False                 True                False
# 3               False                False                 True
# 4               False                 True                False
#
#    Exterior1st_WdShing
# 0                False
# 1                False
# 2                False
# 3                False
# 4                False
#
# [5 rows x 38 columns]

# %% [markdown]
# Splitting Dataset into Training and Testing
# X and Y splitting (i.e. Y is the SalePrice column and the rest of the other columns are X)

# %%
from sklearn.metrics import mean_absolute_error
from sklearn.model_selection import train_test_split

X = df_final.drop(['SalePrice'], axis=1)
Y = df_final['SalePrice']

# Split the training set into
# training and validation set
X_train, X_test, y_train, y_test = train_test_split(
    X, Y, train_size=0.8, test_size=0.2, random_state=0)

# %% [markdown]
# **Model and Accuracy**
#
# As we have to train the model to determine the continuous values, so we will be using these regression models.
#
# SVM-Support Vector Machine
#
# Random Forest Regressor
#
# Linear Regressor

# %% [markdown]
# SVM – Support vector Machine

# %%
from sklearn import svm
from sklearn.svm import SVC
from sklearn.metrics import mean_absolute_percentage_error

model_SVR = svm.SVR()
model_SVR.fit(X_train,y_train)
y_pred_svr = model_SVR.predict(X_test)

print(mean_absolute_percentage_error(y_test, y_pred_svr))
# Out:
# 0.1870512931870423

# %% [markdown]
# Random Forest Regression
#
# Random Forest is an ensemble technique that uses multiple of decision trees and can be used for both regression and classification tasks.

# %%
from sklearn.ensemble import RandomForestRegressor

model_RFR = RandomForestRegressor(n_estimators=10)
model_RFR.fit(X_train, y_train)
y_pred_rfr = model_RFR.predict(X_test)

mean_absolute_percentage_error(y_test, y_pred_rfr)
# Out:
# 0.18942070992237525

# %% [markdown]
# Linear Regression predicts the final output-dependent value based on the given independent features. Like, here we have to predict SalePrice depending on features like MSSubClass, YearBuilt, BldgType, Exterior1st etc.

# %%
from sklearn.linear_model import LinearRegression

model_LR = LinearRegression()
model_LR.fit(X_train, y_train)
y_pred_lr = model_LR.predict(X_test)

print(mean_absolute_percentage_error(y_test, y_pred_lr))
# Out:
# 0.1874168384159986

# %% [markdown]
# Conclusion
# Clearly, SVM model is giving better accuracy as the mean absolute error is the least among all the other regressor models i.e. 0.18 approx
